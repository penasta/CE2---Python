# %%
import pandas as pd
import numpy as np

# %%
mat = {"Matrícula":[123,
                   456,
                   789,
                   102,
                   345]}
nom = {"Nome":["joao",
            "maria",
            "jose",
            "julia"]}
mat
# Out:
# {'Matrícula': [123, 456, 789, 102, 345]}

# %%
d1 = [{'nome':"joao",'matricula':123},{'nome':'maria','matricula':456},
 {'nome':'jose','matricula':789},{'nome':'julia','matricula':345}]
d1 = pd.DataFrame(d1)
d1
# Out:
#     nome  matricula
# 0   joao        123
# 1  maria        456
# 2   jose        789
# 3  julia        345

# %%
d2 = [{'nota':"2",'matricula':123},{'nota':'4','matricula':456},
 {'nota':'6','matricula':614},{'nota':'7','matricula':345},
 {'nota':'9','matricula':518}]
d2 = pd.DataFrame(d2)
d2
# Out:
#   nota  matricula
# 0    2        123
# 1    4        456
# 2    6        614
# 3    7        345
# 4    9        518

# %%
d1.merge(d2)
# Out:
#     nome  matricula nota
# 0   joao        123    2
# 1  maria        456    4
# 2  julia        345    7

# %%
costumers = pd.read_csv('https://raw.githubusercontent.com/edunb01/dotfiles/master/olist_customers_dataset.csv')
itens = pd.read_csv('https://raw.githubusercontent.com/edunb01/dotfiles/master/olist_order_items_dataset.csv')
payments = pd.read_csv('https://raw.githubusercontent.com/edunb01/dotfiles/master/olist_order_payments_dataset.csv')
reviews = pd.read_csv('https://raw.githubusercontent.com/edunb01/dotfiles/master/olist_order_reviews_dataset.csv')
orders = pd.read_csv('https://raw.githubusercontent.com/edunb01/dotfiles/master/olist_orders_dataset.csv')
products = pd.read_csv('https://raw.githubusercontent.com/edunb01/dotfiles/master/olist_products_dataset.csv')
sellers = pd.read_csv('https://raw.githubusercontent.com/edunb01/dotfiles/master/olist_sellers_dataset.csv')

# %%
costumers.head(3)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP

# %%
itens.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-05-03 11:05:13  239.9          19.93
# 2  2018-01-18 14:48:30  199.0          17.87

# %%
payments.head(3)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71

# %%
reviews.head(3)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
# 2             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24

# %%
orders.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00

# %%
products.head(3)
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
# 2  96bd76ec8810374ed1b65e291975717f         esporte_lazer
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0

# %%
sellers.head(3)
# Out:
#                           seller_id  seller_zip_code_prefix     seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023        campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844      mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031  rio de janeiro
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ

# %%
df = itens.merge(payments)
df.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-09-19 09:45:35   58.9          13.29                   1  credit_card
# 1  2017-05-03 11:05:13  239.9          19.93                   1  credit_card
# 2  2018-01-18 14:48:30  199.0          17.87                   1  credit_card
#
#    payment_installments  payment_value
# 0                     2          72.19
# 1                     3         259.83
# 2                     5         216.87

# %%
df = df.merge(sellers)
df.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  0188777fe321843a18be24a6e9aa1e53              1
# 2  0191bbb5166d4b9a68df11797d5acfa9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  436c8d57ff8d4aa254318e9bd9b48c83  48436dade18ac8b2bce089ec2a041202
# 2  ec02a5d380128f7a188e9ce8f3ddd832  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-09-19 09:45:35   58.9          13.29                   1  credit_card
# 1  2017-07-31 14:35:11   55.9           9.94                   1      voucher
# 2  2017-08-16 12:30:15  132.9          20.17                   1  credit_card
#
#    payment_installments  payment_value  seller_zip_code_prefix    seller_city  \
# 0                     2          72.19                   27277  volta redonda
# 1                     1          65.84                   27277  volta redonda
# 2                     4         153.07                   27277  volta redonda
#
#   seller_state
# 0           SP
# 1           SP
# 2           SP

# %%
df = df.merge(products)
df.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-09-19 09:45:35   58.9          13.29                   1  credit_card
# 1  2017-07-05 02:44:11   55.9          17.96                   1       boleto
# 2  2018-05-23 10:56:25   64.9          18.33                   1  credit_card
#
#    payment_installments  ...    seller_city  seller_state  \
# 0                     2  ...  volta redonda            SP
# 1                     1  ...  volta redonda            SP
# 2                     2  ...  volta redonda            SP
#
#   product_category_name product_name_lenght product_description_lenght  \
# 0            cool_stuff                58.0                      598.0
# 1            cool_stuff                58.0                      598.0
# 2            cool_stuff                58.0                      598.0
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 4.0             650.0               28.0                9.0
# 1                 4.0             650.0               28.0                9.0
# 2                 4.0             650.0               28.0                9.0
#
#    product_width_cm
# 0              14.0
# 1              14.0
# 2              14.0
#
# [3 rows x 22 columns]

# %%
df = df.merge(reviews)
df.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-09-19 09:45:35   58.9          13.29                   1  credit_card
# 1  2017-07-05 02:44:11   55.9          17.96                   1       boleto
# 2  2018-05-23 10:56:25   64.9          18.33                   1  credit_card
#
#    payment_installments  ...  product_weight_g  product_length_cm  \
# 0                     2  ...             650.0               28.0
# 1                     1  ...             650.0               28.0
# 2                     2  ...             650.0               28.0
#
#   product_height_cm product_width_cm                         review_id  \
# 0               9.0             14.0  97ca439bc427b48bc1cd7177abe71365
# 1               9.0             14.0  b11cba360bbe71410c291b764753d37f
# 2               9.0             14.0  af01c4017c5ab46df6cc810e069e654a
#
#    review_score  review_comment_title  \
# 0             5                   NaN
# 1             5                   NaN
# 2             4       super recomendo
#
#                               review_comment_message  review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.   2017-09-21 00:00:00
# 1  lannister como sempre, entregou certinho e den...   2017-07-14 00:00:00
# 2                              carrinho muito bonito   2018-06-05 00:00:00
#
#    review_answer_timestamp
# 0      2017-09-22 10:57:03
# 1      2017-07-17 12:50:07
# 2      2018-06-06 21:41:12
#
# [3 rows x 28 columns]

# %%
df = df.merge(orders)
df.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-09-19 09:45:35   58.9          13.29                   1  credit_card
# 1  2017-07-05 02:44:11   55.9          17.96                   1       boleto
# 2  2018-05-23 10:56:25   64.9          18.33                   1  credit_card
#
#    payment_installments  ...  \
# 0                     2  ...
# 1                     1  ...
# 2                     2  ...
#
#                               review_comment_message  review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.   2017-09-21 00:00:00
# 1  lannister como sempre, entregou certinho e den...   2017-07-14 00:00:00
# 2                              carrinho muito bonito   2018-06-05 00:00:00
#
#   review_answer_timestamp                       customer_id order_status  \
# 0     2017-09-22 10:57:03  3ce436f183e68e07877b285a838db11a    delivered
# 1     2017-07-17 12:50:07  e6eecc5a77de221464d1c4eaff0a9b64    delivered
# 2     2018-06-06 21:41:12  4ef55bf80f711b372afebcb7c715344a    delivered
#
#    order_purchase_timestamp    order_approved_at  \
# 0       2017-09-13 08:59:02  2017-09-13 09:45:35
# 1       2017-06-28 11:52:20  2017-06-29 02:44:11
# 2       2018-05-18 10:25:53  2018-05-18 12:31:43
#
#    order_delivered_carrier_date  order_delivered_customer_date  \
# 0           2017-09-19 18:34:16            2017-09-20 23:43:48
# 1           2017-07-05 12:00:33            2017-07-13 20:39:29
# 2           2018-05-23 14:05:00            2018-06-04 18:34:26
#
#    order_estimated_delivery_date
# 0            2017-09-29 00:00:00
# 1            2017-07-26 00:00:00
# 2            2018-06-07 00:00:00
#
# [3 rows x 35 columns]

# %%
df = df.merge(costumers)
df.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-09-19 09:45:35   58.9          13.29                   1  credit_card
# 1  2017-07-05 02:44:11   55.9          17.96                   1       boleto
# 2  2018-05-23 10:56:25   64.9          18.33                   1  credit_card
#
#    payment_installments  ...  order_status  order_purchase_timestamp  \
# 0                     2  ...     delivered       2017-09-13 08:59:02
# 1                     1  ...     delivered       2017-06-28 11:52:20
# 2                     2  ...     delivered       2018-05-18 10:25:53
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-09-13 09:45:35          2017-09-19 18:34:16
# 1  2017-06-29 02:44:11          2017-07-05 12:00:33
# 2  2018-05-18 12:31:43          2018-05-23 14:05:00
#
#   order_delivered_customer_date  order_estimated_delivery_date  \
# 0           2017-09-20 23:43:48            2017-09-29 00:00:00
# 1           2017-07-13 20:39:29            2017-07-26 00:00:00
# 2           2018-06-04 18:34:26            2018-06-07 00:00:00
#
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  871766c5855e863f6eccc05f988b23cb                     28013
# 1  0fb8e3eab2d3e79d92bb3fffbb97f188                     75800
# 2  3419052c8c6b45daf79c1e426f9e9bcb                     30720
#
#            customer_city  customer_state
# 0  campos dos goytacazes              RJ
# 1                  jatai              GO
# 2         belo horizonte              MG
#
# [3 rows x 39 columns]

# %%
df.review_score.mean()
# Out:
# 4.031467071227063

# %%
dataset = pd.DataFrame(df.review_comment_message,df.review_score)
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\toled\Documents\UnB\CE2 - Python\aula11.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/toled/Documents/UnB/CE2%20-%20Python/aula11.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> dataset = df.review_comment_message
#       <a href='vscode-notebook-cell:/c%3A/Users/toled/Documents/UnB/CE2%20-%20Python/aula11.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> dataset
#
# NameError: name 'df' is not defined
